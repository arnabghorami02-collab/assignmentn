# %% [markdown]
# # Power BI Visuals
#
#  1 : Create a Card Visual to show Total Sales.
#
#  Sol :
#  - Measure: Total Sales = SUM(Sales)
# - Result: $12,642,501.91
#
# 2  : Create a Donut Chart showing Total Sales by Ship Mode and which ship mode generates the
# highest sales?
#
# Sol :
# ![image.png](data:image/png;base64,...)
#
#
# 3 : Create a Line Chart showing the Sales Trend over time (by Month and Year). Is there any
# noticeable seasonal pattern in sales?
#
# Sol :
#
# - Axis: Order Date (Month-Year)
# - Value: Sum of Sales
#
# Observation:
#
# - Sales generally increase over time.
# - Higher sales are observed in November and December, indicating a strong year-end seasonal pattern.
# - Lower sales occur during the beginning of the year.
#
# 4 : Create a Bar Chart to compare Sales by Category.
#
# Sol :
# ![image.png](data:image/png;base64,...)
#
#  5 : Create a Matrix Visual to display Sales by Month and Category and identify the month with the
# highest sales.
#
# Sol :
# - Rows: Month
# - Columns: Category
# - Values: Sum of Sales
#
#  6 : Create a Decomposition Tree for Sales Breakdown.
#
#  Sol :
#  Suggested Hierarchy:
#
#  Sales
#  ├── Market
#  │    ├── Country
#  │    │    ├── Category
#  │    │    │    └── Sub-Category
#
#  Insight: This visual helps identify which market, country, category, and sub-category contribute most to sales.
#
#   7 : Create a Scatter Chart to compare Discount vs. Profit by Sub-Category. Are there any outliers
# where high discounts resulted in negative profit?
#
# Sol :
# - X-Axis: Discount
# - Y-Axis: Profit
# - Details: Sub-Category
#
# Observation:
#
# - Several sub-categories show negative profit at higher discount levels.
# - High discounts often reduce profitability.
# - These points can be treated as potential outliers.
#
# 8 : Use a Funnel Chart to show the number of orders by Customer Segment.
#
# Sol :
# ![image.png](data:image/png;base64,...)
#
#
# 9 : Use a Waterfall Chart to analyze how Profit changes by Category within the countries
#
# Sol :
# - Category: Country / Category
# - Value: Profit
#
# Observation:
#
# - Technology generally contributes positively to profit.
# - Some country-category combinations reduce overall profit and appear as negative bars.
#
# 10 : Create a Dual-Axis Line Chart to show Total Sales and Profit Over Time (by Month)
#
# Sol :
#
# - X-Axis: Month
# - Primary Y-Axis: Sales
# - Secondary Y-Axis: Profit
#
# Observation:
#
# - Sales and profit generally move in the same direction.
# - Profit peaks during high-sales months (especially near year-end).
# - Some months may show high sales but relatively lower profit due to discounts or costs.
